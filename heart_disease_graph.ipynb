# %%
print("Name:swarnim")
print("We will be cleaning heart disease data, and conclude which age group has high risk of heart stroke as per diabetes and hight blood pressure level")
print("We will also find which gender has the most not normal platelets count in blood, and plot a pie chart around it")
# Out:
# Name:swarnim
# We will be cleaning heart disease data, and conclude which age group has high risk of heart stroke as per diabetes and hight blood pressure level
# We will also find which gender has the most not normal platelets count in blood, and plot a pie chart around it

# %% [markdown]
# # Task 1 - Find the diabetic and hight blood pressure patients across all age groups, and conclude the risk heart stroke is higher in which age group

# %%
#Import libraries
import pandas as pd
import matplotlib.pyplot as plt 

#read the csv
df = pd.read_csv('heart_disease.csv')
df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  gender  \
# 0                      1  265000.00               1.9           130       1
# 1                      0  263358.03               1.1           136       1
# 2                      0  162000.00               1.3           129       1
# 3                      0  210000.00               1.9           137       1
# 4                      0  327000.00               2.7           116       0
# ..                   ...        ...               ...           ...     ...
# 294                    1  155000.00               1.1           143       1
# 295                    0  270000.00               1.2           139       0
# 296                    0  742000.00               0.8           138       0
# 297                    0  140000.00               1.4           140       1
# 298                    0  395000.00               1.6           136       1
#
#      smoking  time  DEATH_EVENT
# 0          0     4            1
# 1          0     6            1
# 2          1     7            1
# 3          0     7            1
# 4          0     8            1
# ..       ...   ...          ...
# 294        1   270            0
# 295        0   271            0
# 296        0   278            0
# 297        1   280            0
# 298        1   285            0
#
# [299 rows x 13 columns]

# %%
#Filter by diabetes(condition will be who has diabetes) and create new dataframe
diabetes = df.loc[df['diabetes'] == 1].reset_index()
diabetes
# Out:
#      index   age  anaemia  creatinine_phosphokinase  diabetes  \
# 0        4  65.0        1                       160         1
# 1        7  60.0        1                       315         1
# 2       19  48.0        1                       582         1
# 3       21  65.0        1                       128         1
# 4       23  53.0        0                        63         1
# ..     ...   ...      ...                       ...       ...
# 120    290  45.0        0                       615         1
# 121    292  52.0        0                       190         1
# 122    293  63.0        1                       103         1
# 123    294  62.0        0                        61         1
# 124    296  45.0        0                      2060         1
#
#      ejection_fraction  high_blood_pressure  platelets  serum_creatinine  \
# 0                   20                    0   327000.0               2.7
# 1                   60                    0   454000.0               1.1
# 2                   55                    0    87000.0               1.9
# 3                   30                    1   297000.0               1.6
# 4                   60                    0   368000.0               0.8
# ..                 ...                  ...        ...               ...
# 120                 55                    0   222000.0               0.8
# 121                 38                    0   382000.0               1.0
# 122                 35                    0   179000.0               0.9
# 123                 38                    1   155000.0               1.1
# 124                 60                    0   742000.0               0.8
#
#      serum_sodium  gender  smoking  time  DEATH_EVENT
# 0             116       0        0     8            1
# 1             131       1        1    10            1
# 2             121       0        0    15            1
# 3             136       0        0    20            1
# 4             135       1        0    22            0
# ..            ...     ...      ...   ...          ...
# 120           141       0        0   257            0
# 121           140       1        1   258            0
# 122           136       1        1   270            0
# 123           143       1        1   270            0
# 124           138       0        0   278            0
#
# [125 rows x 14 columns]

# %%
#On this new data frame perform group operation as per age and create new dataframe 
age_group = diabetes.groupby('age')['diabetes'].count().reset_index()
age_group
# Out:
#        age  diabetes
# 0   40.000         2
# 1   42.000         2
# 2   44.000         2
# 3   45.000        11
# 4   46.000         1
# 5   48.000         2
# 6   49.000         1
# 7   50.000        12
# 8   51.000         2
# 9   52.000         2
# 10  53.000         3
# 11  54.000         1
# 12  55.000         4
# 13  56.000         1
# 14  58.000         5
# 15  59.000         3
# 16  60.000        19
# 17  60.667         2
# 18  61.000         2
# 19  62.000         3
# 20  63.000         4
# 21  65.000        15
# 22  66.000         1
# 23  68.000         2
# 24  69.000         1
# 25  70.000         9
# 26  72.000         2
# 27  73.000         1
# 28  75.000         3
# 29  80.000         3
# 30  82.000         2
# 31  90.000         1
# 32  94.000         1

# %%
#Filter by high_blood_pressure(condition will be who has high_blood_pressure) and create new dataframe
high_blood_pressure = df.loc[df['high_blood_pressure'] == 1].reset_index()
high_blood_pressure
# Out:
#      index   age  anaemia  creatinine_phosphokinase  diabetes  \
# 0        0  75.0        0                       582         0
# 1        5  90.0        1                        47         0
# 2        9  80.0        1                       123         0
# 3       10  75.0        1                        81         0
# 4       11  62.0        0                       231         0
# ..     ...   ...      ...                       ...       ...
# 100    255  52.0        1                       191         1
# 101    257  58.0        0                       132         1
# 102    270  44.0        0                       582         1
# 103    275  45.0        0                       582         0
# 104    294  62.0        0                        61         1
#
#      ejection_fraction  high_blood_pressure  platelets  serum_creatinine  \
# 0                   20                    1  265000.00               1.9
# 1                   40                    1  204000.00               2.1
# 2                   35                    1  388000.00               9.4
# 3                   38                    1  368000.00               4.0
# 4                   25                    1  253000.00               0.9
# ..                 ...                  ...        ...               ...
# 100                 30                    1  334000.00               1.0
# 101                 38                    1  253000.00               1.0
# 102                 30                    1  263358.03               1.6
# 103                 38                    1  422000.00               0.8
# 104                 38                    1  155000.00               1.1
#
#      serum_sodium  gender  smoking  time  DEATH_EVENT
# 0             130       1        0     4            1
# 1             132       1        1     8            1
# 2             133       1        1    10            1
# 3             131       1        1    10            1
# 4             140       1        1    10            1
# ..            ...     ...      ...   ...          ...
# 100           142       1        1   216            0
# 101           139       1        0   230            0
# 102           130       1        1   244            0
# 103           137       0        0   245            0
# 104           143       1        1   270            0
#
# [105 rows x 14 columns]

# %%
#On this new data frame perform group operation as per age and create new dataframe 
age_group_bp = diabetes.groupby('age')['high_blood_pressure'].count().reset_index()
age_group_bp
# Out:
#        age  high_blood_pressure
# 0   40.000                    2
# 1   42.000                    2
# 2   44.000                    2
# 3   45.000                   11
# 4   46.000                    1
# 5   48.000                    2
# 6   49.000                    1
# 7   50.000                   12
# 8   51.000                    2
# 9   52.000                    2
# 10  53.000                    3
# 11  54.000                    1
# 12  55.000                    4
# 13  56.000                    1
# 14  58.000                    5
# 15  59.000                    3
# 16  60.000                   19
# 17  60.667                    2
# 18  61.000                    2
# 19  62.000                    3
# 20  63.000                    4
# 21  65.000                   15
# 22  66.000                    1
# 23  68.000                    2
# 24  69.000                    1
# 25  70.000                    9
# 26  72.000                    2
# 27  73.000                    1
# 28  75.000                    3
# 29  80.000                    3
# 30  82.000                    2
# 31  90.000                    1
# 32  94.000                    1

# %%
#plot the scatter graph to show which age group is more prone to diabetes
plt.figure(figsize=(19,8))
label = age_group['age']
value = age_group['diabetes']
plt.scatter(label,value,label="Number of People",color="maroon",alpha=0.5,s=value*100)

plt.xlabel("Age",fontsize=15)
plt.ylabel("No. of people prone to have diabetes",fontsize=15)
plt.title("NUMBER OF PEOPLE PRONE TO HAVE DIABETES IN VARIOUS AGES",fontsize=25)
plt.legend()

plt.show()

# %% [markdown]
# Conclusion - age group 60-70 has highest chance of having diabetes.

# %% [markdown]
# # Task 2 - Find as per gender who has not normal platelets level in blood

# %%
#Filter by platelets(condition lesser then 150000 OR greater then 450000) and create new dataframe
abnormal_platelets = df.loc[(df['platelets'] < 150000) | (df['platelets'] > 450000)].reset_index()
abnormal_platelets
# Out:
#     index   age  anaemia  creatinine_phosphokinase  diabetes  \
# 0       6  75.0        1                       246         0
# 1       7  60.0        1                       315         1
# 2      12  45.0        1                       981         0
# 3      15  82.0        1                       379         0
# 4      19  48.0        1                       582         1
# 5      25  80.0        0                       148         1
# 6      47  60.0        0                       582         1
# 7      48  80.0        1                       553         0
# 8      55  95.0        1                       371         0
# 9      65  60.0        0                        68         0
# 10     69  65.0        0                       113         1
# 11     71  58.0        0                       582         1
# 12     73  65.0        0                       224         1
# 13    102  80.0        0                       898         0
# 14    105  72.0        1                       328         0
# 15    109  45.0        0                       292         1
# 16    117  85.0        1                       102         0
# 17    123  60.0        1                       582         0
# 18    163  50.0        1                      2334         1
# 19    167  59.0        0                        66         1
# 20    176  69.0        0                      1419         0
# 21    177  49.0        1                        69         0
# 22    194  45.0        0                       582         0
# 23    200  63.0        1                      1767         0
# 24    211  50.0        0                       582         0
# 25    212  78.0        0                       224         0
# 26    223  47.0        0                       582         0
# 27    224  58.0        0                       582         1
# 28    227  55.0        1                      2794         0
# 29    230  60.0        0                       166         0
# 30    240  70.0        0                        81         1
# 31    264  61.0        0                       582         1
# 32    267  56.0        1                       135         1
# 33    277  70.0        0                       582         1
# 34    279  55.0        0                        84         1
# 35    281  70.0        0                       582         0
# 36    287  45.0        0                       582         1
# 37    291  60.0        0                       320         0
# 38    296  45.0        0                      2060         1
# 39    297  45.0        0                      2413         0
#
#     ejection_fraction  high_blood_pressure  platelets  serum_creatinine  \
# 0                  15                    0   127000.0              1.20
# 1                  60                    0   454000.0              1.10
# 2                  30                    0   136000.0              1.10
# 3                  50                    0    47000.0              1.30
# 4                  55                    0    87000.0              1.90
# 5                  38                    0   149000.0              1.90
# 6                  38                    1   451000.0              0.60
# 7                  20                    1   140000.0              4.40
# 8                  30                    0   461000.0              2.00
# 9                  20                    0   119000.0              2.90
# 10                 25                    0   497000.0              1.83
# 11                 35                    0   122000.0              0.90
# 12                 50                    0   149000.0              1.30
# 13                 25                    0   149000.0              1.10
# 14                 30                    1   621000.0              1.70
# 15                 35                    0   850000.0              1.30
# 16                 60                    0   507000.0              3.20
# 17                 30                    1   127000.0              0.90
# 18                 35                    0    75000.0              0.90
# 19                 20                    0    70000.0              2.40
# 20                 40                    0   105000.0              1.00
# 21                 50                    0   132000.0              1.00
# 22                 20                    1   126000.0              1.60
# 23                 45                    0    73000.0              0.70
# 24                 62                    1   147000.0              0.80
# 25                 50                    0   481000.0              1.40
# 26                 25                    0   130000.0              0.80
# 27                 25                    0   504000.0              1.00
# 28                 35                    1   141000.0              1.00
# 29                 30                    0    62000.0              1.70
# 30                 35                    1   533000.0              1.30
# 31                 38                    0   147000.0              1.20
# 32                 38                    0   133000.0              1.70
# 33                 38                    0    25100.0              1.10
# 34                 38                    0   451000.0              1.30
# 35                 40                    0    51000.0              2.70
# 36                 55                    0   543000.0              1.00
# 37                 35                    0   133000.0              1.40
# 38                 60                    0   742000.0              0.80
# 39                 38                    0   140000.0              1.40
#
#     serum_sodium  gender  smoking  time  DEATH_EVENT
# 0            137       1        0    10            1
# 1            131       1        1    10            1
# 2            137       1        0    11            1
# 3            136       1        0    13            1
# 4            121       0        0    15            1
# 5            144       1        1    23            1
# 6            138       1        1    40            1
# 7            133       1        0    41            1
# 8            132       1        0    50            1
# 9            127       1        1    64            1
# 10           135       1        0    67            1
# 11           139       1        1    71            0
# 12           137       1        1    72            0
# 13           144       1        1    87            0
# 14           138       0        1    88            1
# 15           142       1        1    88            0
# 16           138       0        0    94            0
# 17           145       0        0    95            0
# 18           142       0        0   126            1
# 19           134       1        0   135            1
# 20           135       1        1   147            0
# 21           140       0        0   147            0
# 22           135       1        0   180            1
# 23           137       1        0   186            0
# 24           140       1        1   192            0
# 25           138       1        1   192            0
# 26           134       1        0   201            0
# 27           138       1        0   205            0
# 28           140       1        0   206            0
# 29           127       0        0   207            1
# 30           139       0        0   212            0
# 31           141       1        0   237            0
# 32           140       1        0   244            0
# 33           140       1        0   246            0
# 34           136       0        0   246            0
# 35           136       1        1   250            0
# 36           132       0        0   250            0
# 37           139       1        0   258            0
# 38           138       0        0   278            0
# 39           140       1        1   280            0

# %%
#On this new dataframe perform group operation as per gender and create new dataframe 
gender = abnormal_platelets.groupby('gender')['platelets'].count().reset_index()
gender
# Out:
#    gender  platelets
# 0       0         11
# 1       1         29

# %%
#Plot a pie chart as per the gender to show the percentage of male and female who has not normal platelets
gender['gender'] = ['female','male']
label = gender['gender']
value = gender['platelets']

plt.pie(value,labels=label,autopct="%0.2f%%",radius=2)
plt.show()

# %% [markdown]
# Conclusion - more males have abnormal platelets than females

# %%
print("thank you!")
# Out:
# thank you!
